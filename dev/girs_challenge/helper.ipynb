# %%
import pandas as pd

# %%
df = pd.read_csv('./challenge_source_data.csv')
df['risk'] = df['wear']*df['weather']*df['vegetation']

# %%
df = df.iloc[: , 1:]

# %%
df['id']= range(1, len(df) + 1)

# %%
df.to_csv('new-data.csv',index=False)

# %%
df
# Out:
#                                               geometry  wear   weather  \
# 0    {'bbox': [-121.76321817174035, 38.546501023184...  1.00  0.730345
# 1    {'bbox': [-121.67667135479978, 38.432542118553...  0.70  0.857055
# 2    {'bbox': [-121.7478583069657, 38.5451747098774...  0.65  0.701924
# 3    {'bbox': [-121.7352004762769, 38.5457539788688...  1.00  0.936968
# 4    {'bbox': [-121.76474925009732, 38.548319691768...  0.50  0.549898
# ..                                                 ...   ...       ...
# 145  {'bbox': [-121.71580494093655, 37.711291909593...  0.60  0.543317
# 146  {'bbox': [-121.7046885286235, 37.7005546493609...  0.75  0.914409
# 147  {'bbox': [-121.706038329478, 37.70053917340372...  0.45  0.847403
# 148  {'bbox': [-121.87089313701294, 37.996970710939...  0.70  0.569021
# 149  {'bbox': [-119.76198939522524, 37.230024714922...  0.75  0.803378
#
#      vegetation                 names      risk   id
# 0      0.696342    Lillian Brown Line  0.508570    1
# ...

# %%
df2 = df[:1]
df2.to_csv('test-data.csv', index=False, header=False)

# %%
df2
# Out:
#                                             geometry  wear   weather  \
# 0  {'bbox': [-121.76321817174035, 38.546501023184...   1.0  0.730345
#
#    vegetation               names     risk
# 0    0.696342  Lillian Brown Line  0.50857
